# %% [markdown]
# Write a function to find the value associated with a given key in a BST and to update the value associated with a given key in a BST.

# %%
class BSTNode:
    def __init__(self,key,value):
        self.key = key
        self.value = value
        self.left = None
        self.right = None

# %%
node = BSTNode(7,'seven')
node.left = BSTNode(3,'three')
node.left.left = BSTNode(2,'two')
node.left.right = BSTNode(4,'four')
node.right = BSTNode(11,'eleven')
node.right.left = BSTNode(9,'nine')
node.right.right = BSTNode(12,'twelve')

# %%
def find(node,key):
    
    if node is None:
        return None
    elif key == node.key:
        return node.value
    elif key < node.key:
        return find1(node.left,key)
    else:
        return find1(node.right,key)

# %%
print(find(node,4))
print(find(node,15))
# Out:
# four
# None

# %%
def update(node,key,value):
    if node is None:
        pass
    elif key == node.key:
        node.value = value
    elif key < node.key:
        update(node.left,key,value)
    else:
        update(node.right,key,value)

# %%
update(node,4,'FOUR')
update(node,15,'FIFTEEN')

# %%
node.left.right.value
# Out:
# 'FOUR'
